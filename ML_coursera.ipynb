# %% [markdown]
# ## MACHINE LEARNING COURSE COMPLETED ON COURSERA

# %% [markdown]
# All the work has been submitted on coursera. No files created locally.

# %% [markdown]
# ![image.png](attachment:image.png)
